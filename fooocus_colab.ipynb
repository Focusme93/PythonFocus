# %%
# Устанавливаем версии, которые работают вместе
# !pip install numpy==1.26.4 --force-reinstall
# !pip install gradio==3.50.2 --force-reinstall
# !pip install transformers==4.41.2 --force-reinstall
# !pip install accelerate==0.31.0 --force-reinstall
# !pip install onnxruntime==1.17.3 --force-reinstall

# Удаляем проблемный CuPy (чтобы не конфликтовал)
# !pip uninstall cupy-cuda12x cupy-cuda11x cupy -y

# Устанавливаем pygit2
# !pip install pygit2==1.15.1

# Перезапуск
import os
os.kill(os.getpid(), 9)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
